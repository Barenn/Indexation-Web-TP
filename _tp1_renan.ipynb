# %% [markdown]
# # Indexation Web - TP1
# BERNARD Renan
#
# ## Introduction
#
# Tout d'abord les différentes importations nécessaires pour ce Notebook.
# Les fonctions utilisées sont dans le fichier __utils.py__.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import re
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import pickle

from functools import reduce

from utils import *
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Indexation
#
# ### Données
#
# Récupérons ensuite l'ensemble des données. Nous garderons un DataFrame contenons le texte, l'auteur et l'identifiant du document.

# %%
# %%time
texts = generate_texts_dataframe()
texts.head()
# Out:
# CPU times: user 203 ms, sys: 75.4 ms, total: 278 ms
# Wall time: 566 ms
#                                                 Text            Author  \
# 0  Russia's Fuel and Energy Ministry, sitting on ...  Lynnley Browning
# 1  Russia's Western oil joint ventures are findin...  Lynnley Browning
# 2  Russian oil company officials said on Friday t...  Lynnley Browning
# 3  Azerbaijan is proving more successful in attra...  Lynnley Browning
# 4  A multinational group trying to build a $1.5 b...  Lynnley Browning
#
#   DocumentId
# 0     116673
# 1     248885
# 2     314644
# 3     219830
# 4     239689

# %% [markdown]
# Lisons quelques articles.

# %%
view_article(10, texts)
view_article(102, texts)
# Out:
# --------------------------------------------
# Author : Lynnley Browning
# Id : 114005
# --------------------------------------------
# Aluminium industry sources expressed doubt on Monday over whether producers association Kontsern Alyuminiy would be able to contain output to support sagging world prices.
# "I don't believe they'll do it," said a Western trade source in Moscow.
# A Moscow representative of the Krasnoyarsk smelter and two sources at the giant Bratsk plant said they had no information on plans to contain output.
# "This is a very strategic question on which I have no information," said Bratsk-based Andrei Toropovsky of the plant's foreign economic relations department.
# Kontsern Alyuminiy chief executive Igor Prokopov said Russian smelters had agreed to keep aluminium output at current levels and not to exploit at least 80,000-100,000 tonnes of idle annual capacity.
# He and Vladimir Kalchenko, the group's first deputy chief executive, referred to weak world prices and unprofitable domestic smelters.
# But the sources said Kontsern Alyuminiy had little leverage and was unlikely to be able to influence producers.
# London Metal Exchange (LME) benchmark aluminium prices failed to react seriously and held little changed at $1,330 per tonne in early trade -- a sign that the market may have questions over what the Kontsern Alyuminiy plan means.
# "The smelters tend to do what they want individually," said a European metals source. "I don't care what Kontsern Aluminiy says -- it doesn't affect my business."
# Russia, with high electricity and freight costs and low domestic demand, is keen to see higher world metals prices. Aluminium is near 2-1/2 year lows of $1,305 and far below the $1,742 a tonne seen around this time last year.
# A Russian industry source said profit margins on metal exported at average LME prices in the third quarter of this year were a negative 20 percent at Russia's Novokuznetsk smelter, negative 15 percent at Kandalaksha and negative 15-18 percent at plants in the Urals region.
# Krasnoyarsk was breaking even, he said. Sayansk and Bratsk had profit margins of plus 10 percent. Irkutsk had 11 percent.
# It costs Bratsk $1,127 to produce a tonne of aluminium, the source said. Freight charges to European outlets added $160 per tonne, leaving gross profits of about $110 per tonne, assuming LME prices of around $1,400.
# "The Siberian smelters have a decent economic situation," said Ruslan Fedorovsky of Barclays Physical Trading Limited in London. "It's profitable for them to let the European smelters (with negative profit margins) die out."
# A Canadian diplomat said last week in Moscow that Russian and Canadian government officials had met to discuss curbing Russian output, rekindling memories of the Memorandum of Understanding (MOU) between major producers Russia, Australia, Canada, the European Union, Norway and the United States.
# The MOU, designed to cut output by 10 percent and draw down bloated stocks, began in March 1994 and expired this spring.
# Adding to uncertainty was a statement by Oleg Deripaska, chief executive officer of Sayansk Aluminium, who said on Friday that he expected a decision on decreasing output.
# But sources said impending Russian purchases of alumina, the raw material for aluminium, would be a better indicator of how much metal Russian smelters plan to produce next year.
# "That will be the telling time," said one source, referring to buying that should take place by the end of the year.
# Trade sources in direct contact with Russian smelters said they would keep an eye on Kontsern Alyuminy, but doubted it could influence the industry.
# "They (Kontsern Alyuminiy) don't really represent smelters and do not have a lot of credibility," one Western source said.
# --Moscow Newsroom +7095 941 8520
#
#
# --------------------------------------------
# Author : Keith Weir
# Id : 164490
# --------------------------------------------
# Investors on both sides of the Atlantic applauded the planned $20 billion merger of British Telecom Plc and MCI Communications of the United States Monday, boosting their shares in stock market trading.
# British, European and U.S. regulators will subject the deal to close scrutiny amid strong opposition to it from rivals, including American long-distance market leader AT&amp;T Corp.
# British Telecom, or BT, as it is known, said it was optimistic that the European Commission would clear the largest cross-border takeover deal in history, which will create one of the largest groups in the rapidly expanding global telecommunications sector.
# Britain's communications industry regulatory agency said it was studying the details of the merger and it was too early to pass judgment.
# BT Chief Executive Sir Peter Bonfield has said it could take a year to clear all the regulatory hurdles.
# BT's shares powered 32-1/2 pence higher to 383 1/2p -- adding around two billion pounds ($3.3 billion) to the company's market value on huge trading volume of over 40 million shares.
# MCI gained $1.25 to $31.50 in early trading on Nasdaq, while AT&amp;T fell $1.125 to $33.50 on the New York Stock Exchange.
# Despite the large cost of the deal to British Telecom -- it will be the biggest-ever acquisition by a British firm -- the deal is seen as having a compelling industrial logic, linking leading phone companies on both sides of the Atlantic.
# For BT shareholders the deal is also being sugared with a promise of a special one-time 35p dividend payout and a higher rate of general dividend increases in the future.
# "It is positive for BT shareholders and positive for the (telecoms) sector," said Jim McCafferty, analyst at ABN AMRO Hoare Govett.
# For customers, the deal promises better service and lower international calling charges, while for businesses it means a company that can support them wherever they are.
# The merged company will be called Concert Plc. It will be the second-largest international carrier after AT&amp;T.
# The deal values all of Washington, D.C.-based MCI at just over $25 billion. Since British Telecom already owns 20 percent of MCI, it will issue Concert stock and cash worth $20.1 billion for the remaining 80 percent. Holders of MCI stock will control a third of the stock in the combined company.
# Larry Stone, BT's head of EU affairs, told Reuters he hoped the deal would be dealt with under the EU's fast-track merger rules and said he did not anticipate any anti-trust problems because the companies "operate in competitive markets."
# Analysts expect British Telecom and MCI to start making overtures to major Asian players such as Japan's giant Nippon Telegraph and Telephone Corp.
# But while seeking an Asian partner, MCI appears to be putting another one on a backburner.
# MCI is to cut its stake in a U.S. satellite television venture with media tycoon Rupert Murdoch to 20 percent from 50 percent, and has said it will probably not increase its stake in Murdoch's News Corp as originally expected.
# MCI paid $1.35 billion for a stake of just under 9 percent, and could increase it to 13 percent with another $1 billion investment.

# %% [markdown]
# ### Préparation des textes
#
# Le premier traitement est la transformation des phrases en un liste de mot, en miniscule, contenant uniquement des caractères numériques. Pour celà, on utilise une expression régulière.
#
# On enlève ensuite les 'stopWords' qui n'apportent pas d'information sur le contenu de l'article.
#
# Puis on a choisis d'utiliser un stemmer. Cette méthode enlève les préfixes et suffixes des mots pour garder uniquement la racine. Celle-ci n'est pas forcement un mot qui existe réellement.
#
# La fonction _tokenize_text_ est aussi présente dans utils avec une meilleure documentation.

# %%
def tokenize_text(text):
    #Imports
    stemmer = PorterStemmer()
    stopWords = set(stopwords.words('english'))
    
    #Expression régulière. Text --> [mots]
    reg_ex = re.compile(r'[A-Za-z]+')
    bag_of_tokens = []
    text = reg_ex.findall(text.lower())
    for word in text:
        #stopWords
        if len(word) > 1 and word not in stopWords:
            #Stemmer
            bag_of_tokens.append(stemmer.stem(word))
    return bag_of_tokens

# %%
# %%time
tokenize_text(texts.Text[0])
# Out:
# CPU times: user 19.8 ms, sys: 3.81 ms, total: 23.6 ms
# Wall time: 23.5 ms
# ['russia',
#  'fuel',
#  'energi',
#  'ministri',
#  'sit',
#  'remain',
#  'great',
#  'power',
#  'wield',
#  'oil',
#  'sector',
#  'struggl',
#  'redefin',
#  'new',
#  'market',
#  'economi',
#  'energi',
#  'analyst',
#  'said',
#  'tuesday',
#  'bodi',
#  'known',
#  'mintopenergo',
#  'could',
#  'command',
#  'oil',
#  'well',
#  'drill',
#  'help',
#  'restrict',
#  'export',
#  'quota',
#  'ensur',
#  'billion',
#  'dollar',
#  'oil',
#  'export',
#  'cash',
#  'world',
#  'third',
#  'largest',
#  'oil',
#  'produc',
#  'went',
#  'kremlin',
#  'coffer',
#  'today',
#  'power',
#  'produc',
#  'export',
#  'plot',
#  'corpor',
#  'strategi',
#  'larg',
#  'lie',
#  'hand',
#  'russia',
#  'newli',
#  'privatis',
#  'vertic',
#  'integr',
#  'oil',
#  'firm',
#  'leav',
#  'ministri',
#  'redefin',
#  'new',
#  'market',
#  'economi',
#  'kind',
#  'use',
#  'word',
#  'castrat',
#  'said',
#  'european',
#  'energi',
#  'consult',
#  'moscow',
#  'new',
#  'minist',
#  'pyotr',
#  'rodionov',
#  'ga',
#  'transport',
#  'specialist',
#  'mintopenergo',
#  'may',
#  'even',
#  'less',
#  'say',
#  'daili',
#  'busi',
#  'oil',
#  'firm',
#  'increasingli',
#  'go',
#  'busi',
#  'cut',
#  'deal',
#  'foreign',
#  'investor',
#  'oil',
#  'compani',
#  'say',
#  'ministri',
#  'guardian',
#  'big',
#  'state',
#  'stake',
#  'could',
#  'becom',
#  'lobbi',
#  'interest',
#  'kremlin',
#  'less',
#  'long',
#  'arm',
#  'politician',
#  'seek',
#  'oil',
#  'profit',
#  'top',
#  'feder',
#  'budget',
#  'undoubtedli',
#  'regulatori',
#  'influenc',
#  'wane',
#  'said',
#  'alexei',
#  'gorshkov',
#  'spokesman',
#  'yuko',
#  'russia',
#  'second',
#  'largest',
#  'oil',
#  'compani',
#  'term',
#  'reserv',
#  'see',
#  'former',
#  'influenc',
#  'frankli',
#  'want',
#  'see',
#  'ministri',
#  'explain',
#  'point',
#  'view',
#  'tax',
#  'govern',
#  'grate',
#  'known',
#  'ministri',
#  'oil',
#  'ga',
#  'industri',
#  'soviet',
#  'era',
#  'mintopenergo',
#  'lost',
#  'respons',
#  'today',
#  'gazprom',
#  'natur',
#  'ga',
#  'monopoli',
#  'renam',
#  'mintopenergo',
#  'exist',
#  'seen',
#  'russia',
#  'state',
#  'run',
#  'oil',
#  'product',
#  'associ',
#  'transform',
#  'privatis',
#  'compani',
#  'multi',
#  'billion',
#  'dollar',
#  'arrang',
#  'western',
#  'oil',
#  'major',
#  'mintopenergo',
#  'brief',
#  'includ',
#  'coal',
#  'electr',
#  'mani',
#  'oil',
#  'specialist',
#  'fled',
#  'ministri',
#  'stalin',
#  'era',
#  'build',
#  'lucr',
#  'job',
#  'invest',
#  'bank',
#  'oil',
#  'firm',
#  'even',
#  'former',
#  'minist',
#  'yuri',
#  'shafranik',
#  'left',
#  'august',
#  'head',
#  'board',
#  'tyumen',
#  'oil',
#  'compani',
#  'whose',
#  'headquart',
#  'siberian',
#  'power',
#  'base',
#  'oil',
#  'rich',
#  'tyumen',
#  'region',
#  'ministri',
#  'simpli',
#  'go',
#  'import',
#  'said',
#  'matthew',
#  'sager',
#  'planecon',
#  'washington',
#  'recent',
#  'interview',
#  'go',
#  'left',
#  'polici',
#  'make',
#  'advisori',
#  'overs',
#  'role',
#  'good',
#  'thing',
#  'mintopenergo',
#  'new',
#  'challeng',
#  'remnant',
#  'power',
#  'base',
#  'form',
#  'feder',
#  'energi',
#  'commiss',
#  'fek',
#  'brainchild',
#  'presidenti',
#  'chief',
#  'staff',
#  'anatoli',
#  'chubai',
#  'fek',
#  'want',
#  'inject',
#  'free',
#  'market',
#  'flavour',
#  'energi',
#  'tariff',
#  'transport',
#  'issu',
#  'although',
#  'unclear',
#  'much',
#  'leeway',
#  'seek',
#  'award',
#  'access',
#  'crowd',
#  'pipelin',
#  'rout',
#  'tender',
#  'thu',
#  'restrict',
#  'power',
#  'oil',
#  'pipelin',
#  'monopoli',
#  'transneft',
#  'non',
#  'oper',
#  'issu',
#  'rodionov',
#  'said',
#  'plan',
#  'polici',
#  'chang',
#  'reveal',
#  'mind',
#  'worri',
#  'industri',
#  'player',
#  'talk',
#  'freez',
#  'domest',
#  'crude',
#  'oil',
#  'price',
#  'aid',
#  'rodionov',
#  'said',
#  'ministri',
#  'foresak',
#  'broad',
#  'brush',
#  'industri',
#  'wide',
#  'approach',
#  'energi',
#  'favour',
#  'concentr',
#  'said',
#  'individu',
#  'matter',
#  'import',
#  'russian',
#  'economi',
#  'like',
#  'tax',
#  'break',
#  'oil',
#  'compani',
#  'one',
#  'western',
#  'oil',
#  'sourc',
#  'said',
#  'interest',
#  'rodionov',
#  'plan',
#  'ministri',
#  'lost',
#  'power',
#  'power',
#  'devolv',
#  'default',
#  'oil',
#  'compani',
#  'ministri',
#  'recognis',
#  'put',
#  'peopl',
#  'compani',
#  'board',
#  'said',
#  'stephen',
#  'sullivan',
#  'associ',
#  'oil',
#  'ga',
#  'director',
#  'mc',
#  'secur',
#  'london']

# %% [markdown]
# ### Vocabulaire
#
# On choisit d'enlever les mots qui n'apparaissent pas assez de fois dans le corpus. En effet, cela signifie qu'ils sont trop rares et qu'ils n'apportent pas assez d'informations utiles.
#
# En gardant les mots qui apparaissent plus de 5 fois, on a un vocabulaire de 7 489 mots.

# %%
vocabulary = create_vocabulary(texts)

vocabulary_dict = create_vocabulary_dict(vocabulary, 5)
print(len(vocabulary_dict))
vocabulary_dict
# Out:
# 7489
# {'ab': 21,
#  'abandon': 33,
#  'abbey': 102,
#  'abc': 13,
#  'abduct': 11,
#  'abf': 18,
#  'abi': 12,
#  'abid': 14,
#  'abidjan': 76,
#  'abil': 115,
#  'abl': 322,
#  'abn': 41,
#  'abnorm': 123,
#  'aboard': 22,
#  'abod': 6,
#  'abolish': 20,
#  'abolit': 8,
#  'abort': 18,
#  'abound': 9,
#  'abroad': 123,
#  'abruptli': 6,
#  'absenc': 18,
#  'absent': 13,
#  'absolut': 46,
#  'absorb': 41,
#  'abus': 35,
#  'ac': 7,
#  'academ': 30,
#  'academi': 20,
#  'acceler': 75,
#  'accept': 279,
#  'access': 395,
#  'accid': 38,
#  'accol': 10,
#  'accomod': 7,
#  'accompani': 32,
#  'accomplish': 19,
#  'accord': 459,
#  'account': 582,
#  'accredit': 6,
#  'accret': 11,
#  'accumul': 17,
#  'accur': 9,
#  'accus': 162,
#  'ace': 7,
#  'achiev': 182,
#  'acid': 29,
#  'acknowledg': 70,
#  'acpc': 28,
#  'acquir': 231,
#  'acquisit': 588,
#  'acquist': 8,
#  'acquitt': 9,
#  'acqusit': 8,
#  'acr': 15,
#  'across': 223,
#  'act': 221,
#  'action': 325,
#  'activ': 529,
#  'activist': 155,
#  'actual': 110,
#  'actuari': 9,
#  'acut': 6,
#  'ad': 1441,
#  'adact': 6,
#  'adam': 15,
#  'adapt': 24,
#  'add': 143,
#  'addict': 11,
#  'addit': 302,
#  'address': 140,
#  'adelaid': 15,
#  'adequ': 26,
#  'adequaci': 16,
#  'adjac': 8,
#  'adjourn': 16,
#  'adjust': 75,
#  'adm': 178,
#  'administ': 9,
#  'administr': 259,
#  'adminstr': 8,
#  'admir': 8,
#  'admiss': 20,
#  'admit': 77,
#  'adopt': 86,
#  'adr': 12,
#  'adrian': 17,
#  'adt': 34,
#  'adult': 28,
#  'advanc': 177,
#  'advantag': 146,
#  'advers': 14,
#  'advert': 12,
#  'advertis': 166,
#  'advic': 35,
#  'advis': 113,
#  'advisor': 23,
#  'advisori': 49,
#  'advoc': 49,
#  'advocaci': 10,
#  'aea': 14,
#  'aero': 29,
#  'aeronautica': 15,
#  'aerospac': 110,
#  'aerospatial': 58,
#  'affair': 127,
#  'affect': 226,
#  'affili': 57,
#  'affirm': 7,
#  'afflict': 8,
#  'affluent': 10,
#  'afford': 61,
#  'afraid': 7,
#  'africa': 95,
#  'african': 71,
#  'afternoon': 123,
#  'afterward': 17,
#  'ag': 94,
#  'age': 142,
#  'agenc': 301,
#  'agenda': 53,
#  'agent': 73,
#  'agf': 29,
#  'aggrav': 8,
#  'aggreg': 7,
#  'aggreko': 8,
#  'aggress': 129,
#  'agip': 6,
#  'agl': 9,
#  'ago': 632,
#  'agre': 518,
#  'agreement': 613,
#  'agribusi': 7,
#  'agricultur': 152,
#  'agro': 10,
#  'ahead': 421,
#  'ahk': 9,
#  'ai': 27,
#  'aid': 164,
#  'aig': 8,
#  'ail': 36,
#  'ailment': 15,
#  'aim': 402,
#  'air': 598,
#  'airbag': 13,
#  'airbu': 360,
#  'aircraft': 212,
#  'airlin': 483,
#  'airmen': 6,
#  'airplan': 41,
#  'airport': 181,
#  'airshow': 8,
#  'airtour': 13,
#  'airwav': 18,
#  'airway': 106,
#  'al': 40,
#  'alain': 31,
#  'alamo': 22,
#  'alan': 32,
#  'alarm': 35,
#  'alaska': 18,
#  'albeit': 13,
#  'albert': 10,
#  'alberta': 6,
#  'albright': 33,
#  'albumin': 6,
#  'alcatel': 47,
#  'alcohol': 22,
#  'ale': 14,
#  'alenia': 8,
#  'alert': 23,
#  'alex': 38,
#  'alexand': 62,
#  'alfonso': 10,
#  'alfr': 9,
#  'alien': 6,
#  'align': 8,
#  'aliv': 12,
#  'allan': 14,
#  'allay': 12,
#  'alleg': 108,
#  'allegedli': 26,
#  'allen': 98,
#  'allevi': 6,
#  'alli': 97,
#  'allianc': 279,
#  'alloc': 55,
#  'allot': 6,
#  'allow': 714,
#  'almost': 236,
#  'alon': 97,
#  'along': 222,
#  'alongsid': 16,
#  'alpex': 7,
#  'alpha': 6,
#  'alreadi': 778,
#  'also': 2698,
#  'alsthom': 30,
#  'altamira': 30,
#  'alter': 51,
#  'altern': 84,
#  'although': 441,
#  'alto': 16,
#  'altogeth': 6,
#  'alumina': 21,
#  'aluminium': 104,
#  'alway': 121,
#  'alyuminiy': 11,
#  'amass': 13,
#  'amato': 9,
#  'ambassador': 27,
#  'ambit': 24,
#  'ambiti': 49,
#  'ambul': 20,
#  'amcor': 17,
#  'amd': 16,
#  'amec': 17,
#  'amelio': 45,
#  'amend': 64,
#  'america': 365,
#  'american': 497,
#  'ameritech': 49,
#  'amic': 53,
#  'amid': 90,
#  'amiel': 12,
#  'amnesti': 6,
#  'amoco': 22,
#  'among': 443,
#  'amongst': 6,
#  'amor': 6,
#  'amort': 11,
#  'amount': 235,
#  'amp': 1277,
#  'ampl': 6,
#  'amr': 22,
#  'amro': 38,
#  'amsterdam': 22,
#  'analog': 7,
#  'analogu': 9,
#  'analys': 19,
#  'analysi': 31,
#  'analyst': 4048,
#  'anatoli': 10,
#  'ancient': 9,
#  'and': 6,
#  'andersen': 10,
#  'anderson': 25,
#  'andi': 12,
#  'andrea': 66,
#  'andreessen': 9,
#  'andrei': 8,
#  'andrew': 49,
#  'anecdot': 7,
#  'angel': 54,
#  'anger': 42,
#  'angl': 8,
#  'anglian': 6,
#  'anglo': 48,
#  'angri': 25,
#  'angular': 6,
#  'anhui': 8,
#  'anim': 56,
#  'ann': 7,
#  'anniversari': 31,
#  'announc': 927,
#  'annual': 431,
#  'annuiti': 6,
#  'annum': 13,
#  'anoint': 18,
#  'anonym': 38,
#  'anoth': 769,
#  'ansett': 33,
#  'anson': 19,
#  'answer': 55,
#  'anthoni': 26,
#  'anti': 211,
#  'anticip': 115,
#  'antiqu': 7,
#  'antitrust': 66,
#  'antonio': 8,
#  'anxieti': 10,
#  'anxiou': 13,
#  'anybodi': 21,
#  'anymor': 15,
#  'anyon': 40,
#  'anysoft': 13,
#  'anyth': 146,
#  'anytim': 7,
#  'anyway': 12,
#  'anywher': 35,
#  'anz': 23,
#  'aol': 125,
#  'aom': 39,
#  'aon': 37,
#  'apart': 51,
#  'apathi': 10,
#  'apec': 22,
#  'aphi': 14,
#  'apolog': 9,
#  'apologis': 9,
#  'appal': 7,
#  'appar': 82,
#  'apparatu': 6,
#  'apparel': 10,
#  'appeal': 266,
#  'appear': 284,
#  'appeas': 7,
#  'appel': 11,
#  'appetit': 12,
#  'appl': 398,
#  'applaud': 22,
#  'applegarth': 22,
#  'appli': 123,
#  'applianc': 15,
#  'applic': 214,
#  'appoint': 138,
#  'appointe': 6,
#  'apprais': 12,
#  'appreci': 27,
#  'approach': 197,
#  'appropri': 53,
#  'approv': 466,
#  'approxim': 19,
#  'april': 225,
#  'aquitain': 7,
#  'ar': 33,
#  'arab': 13,
#  'arabia': 16,
#  'arbitr': 28,
#  'arbitrag': 27,
#  'arbor': 8,
#  'arc': 10,
#  'arch': 33,
#  'archer': 22,
#  'architect': 13,
#  'architectur': 9,
#  'archriv': 13,
#  'arctic': 7,
#  'area': 586,
#  'arena': 32,
#  'arequipa': 14,
#  'argentina': 26,
#  'argonaut': 7,
#  'argu': 154,
#  'argument': 51,
#  'aria': 10,
#  'arian': 7,
#  'aris': 39,
#  'aristo': 11,
#  'arizona': 10,
#  'arkansa': 11,
#  'arl': 9,
#  'arlen': 19,
#  'arm': 254,
#  'armi': 130,
#  'armstrong': 20,
#  'arnold': 11,
#  'aros': 9,
#  'around': 921,
#  'arous': 6,
#  'arrang': 103,
#  'array': 13,
#  'arrear': 8,
#  'arrest': 67,
#  'arriv': 184,
#  'art': 26,
#  'arthui': 14,
#  'arthur': 22,
#  'articl': 62,
#  'artifici': 12,
#  'artist': 23,
#  'asa': 8,
#  'asahi': 9,
#  'ascend': 8,
#  'asda': 21,
#  'ashland': 41,
#  'asia': 436,
#  'asian': 257,
#  'asid': 48,
#  'ask': 459,
#  'askatindo': 6,
#  'askyb': 9,
#  'aspect': 30,
#  'aspir': 7,
#  'assassin': 13,
#  'assault': 12,
#  'assembl': 163,
#  'assert': 10,
#  'assess': 45,
#  'asset': 588,
#  'assign': 20,
#  'assist': 85,
#  'associ': 371,
#  'assum': 49,
#  'assumpt': 14,
#  'assur': 80,
#  'asthma': 17,
#  'astra': 10,
#  'astrolog': 10,
#  'asylum': 14,
#  'ata': 8,
#  'atkin': 9,
#  'atlant': 73,
#  'atlanta': 42,
#  'atm': 36,
#  'atmospher': 14,
#  'atp': 13,
#  'attach': 19,
#  'attack': 131,
#  'attain': 14,
#  'attempt': 155,
#  'attend': 106,
#  'attent': 97,
#  'attitud': 34,
#  'attorney': 93,
#  'attract': 266,
#  'attribut': 69,
#  'attrit': 6,
#  'auchard': 6,
#  'auction': 129,
#  'audi': 13,
#  'audienc': 40,
#  'audio': 16,
#  'audit': 14,
#  'auditor': 10,
#  'aug': 20,
#  'august': 298,
#  'aussi': 7,
#  'auster': 12,
#  'australia': 358,
#  'australian': 369,
#  'austria': 8,
#  'author': 430,
#  'authoris': 35,
#  'auto': 228,
#  'autom': 18,
#  'automak': 280,
#  'automat': 24,
#  'automobil': 26,
#  'automot': 104,
#  'auton': 27,
#  'autonom': 16,
#  'autonomi': 42,
#  'autumn': 18,
#  'avail': 299,
#  'aveng': 8,
#  'avenu': 18,
#  'averag': 341,
#  'avert': 16,
#  'avi': 9,
#  'avian': 30,
#  'aviat': 64,
#  'avion': 6,
#  'avoid': 114,
#  'aw': 9,
#  'awa': 9,
#  'await': 87,
#  'awar': 62,
#  'award': 83,
#  'awash': 6,
#  'away': 209,
#  'awu': 8,
#  'axa': 9,
#  'axe': 6,
#  'ayl': 13,
#  'azerbaijan': 11,
#  'azeri': 11,
#  'ba': 71,
#  'babi': 60,
#  'bach': 6,
#  'back': 883,
#  'backbon': 16,
#  'backdrop': 9,
#  'backer': 14,
#  'backfir': 6,
#  'background': 33,
#  'backlash': 13,
#  'backlog': 28,
#  'backoffic': 8,
#  'backpack': 7,
#  'backward': 24,
#  'bacterium': 6,
#  'bad': 167,
#  'badli': 41,
#  'bae': 40,
#  'baesema': 12,
#  'bag': 76,
#  'baht': 10,
#  'bail': 35,
#  'bake': 6,
#  'baker': 53,
#  'balanc': 220,
#  'ball': 16,
#  'balloon': 15,
#  'ballot': 56,
#  'baltimor': 20,
#  'ban': 298,
#  'bancorp': 10,
#  'bancshar': 13,
#  'band': 45,
#  'bang': 34,
#  'bangkok': 25,
#  'bank': 3213,
#  'banka': 96,
#  'bankboston': 12,
#  'banker': 119,
#  'bankrupt': 19,
#  'bankruptci': 69,
#  'banner': 36,
#  'banqu': 6,
#  'bar': 64,
#  'barad': 13,
#  'barbi': 7,
#  'barcep': 9,
#  'barclay': 41,
#  'bare': 113,
#  'bargain': 95,
#  'barksdal': 28,
#  'barley': 14,
#  'barlow': 6,
#  'barn': 17,
#  'barnett': 14,
#  'barney': 53,
#  'baromet': 6,
#  'baron': 15,
#  'barr': 6,
#  'barrel': 44,
#  'barrett': 7,
#  'barri': 26,
#  'barricad': 6,
#  'barrick': 249,
#  'barrier': 65,
#  'barron': 18,
#  'barton': 12,
#  'base': 1661,
#  'basebal': 21,
#  'basf': 6,
#  'bash': 7,
#  'basi': 188,
#  'basic': 177,
#  'basket': 52,
#  'bass': 72,
#  'bat': 11,
#  'batch': 14,
#  'battalion': 6,
#  'battenberg': 8,
#  'batter': 22,
#  'batteri': 18,
#  'battl': 191,
#  'bavarian': 6,
#  'bawc': 8,
#  'baxter': 22,
#  'bay': 75,
#  'bba': 6,
#  'bbc': 63,
#  'bcci': 17,
#  'bcm': 13,
#  'beach': 16,
#  'beam': 9,
#  'bean': 87,
#  'bear': 67,
#  'bearish': 18,
#  'beat': 83,
#  'beatti': 20,
#  'beaubien': 11,
#  'beauti': 19,
#  'becam': 116,
#  'becker': 28,
#  'becom': 549,
#  'bed': 13,
#  'beecham': 9,
#  'beef': 36,
#  'beer': 153,
#  'beforehand': 6,
#  'began': 218,
#  'begin': 295,
#  'begun': 67,
#  'behalf': 33,
#  'behaviour': 7,
#  'behemoth': 8,
#  'behind': 239,
#  'behren': 6,
#  'beifang': 8,
#  'beij': 1286,
#  'beiris': 7,
#  'beleagu': 11,
#  'belgian': 12,
#  'belgium': 11,
#  'belhassin': 9,
#  'belief': 31,
#  'believ': 471,
#  'bell': 218,
#  'belli': 8,
#  'bellsouth': 22,
#  'bellweth': 8,
#  'belong': 25,
#  'belt': 23,
#  'bench': 6,
#  'benchmark': 42,
#  'benefici': 10,
#  'beneficiari': 10,
#  'benefit': 349,
#  'bensdorp': 24,
#  'benson': 10,
#  'benz': 34,
#  'berger': 12,
#  'berkeley': 11,
#  'berlusconi': 13,
#  'bernard': 16,
#  'bernstein': 7,
#  'bert': 7,
#  'besid': 15,
#  'besley': 8,
#  'best': 282,
#  'bet': 42,
#  'bethesda': 7,
#  'bett': 6,
#  'better': 447,
#  'beverag': 52,
#  'beyond': 95,
#  'bhp': 90,
#  'bi': 31,
#  'bia': 14,
#  'bibf': 8,
#  'bid': 943,
#  'bidder': 110,
#  'bierdeman': 7,
#  'big': 789,
#  'bigger': 84,
#  'biggest': 519,
#  'bilater': 42,
#  'bill': 373,
#  'billboard': 7,
#  'billion': 3107,
#  'billionair': 16,
#  'bin': 8,
#  'bind': 17,
#  'bioproduct': 6,
#  'biotech': 75,
#  'biotechnolog': 20,
#  'bird': 26,
#  'birmingham': 12,
#  'birt': 12,
#  'birth': 16,
#  'birthday': 6,
#  'biscuit': 7,
#  'bishop': 9,
#  'bit': 160,
#  'bite': 18,
#  'bitter': 37,
#  'bitterli': 7,
#  'bizarr': 6,
#  'black': 86,
#  'blacklist': 8,
#  'blair': 12,
#  'blame': 113,
#  'blanc': 21,
#  'blanket': 6,
#  'blaschk': 6,
#  'blast': 47,
#  'blaze': 9,
#  'bleak': 8,
#  'bleasel': 8,
#  'bleed': 7,
#  'blend': 6,
#  'blenheim': 39,
#  'bless': 16,
#  'blew': 7,
#  'blind': 11,
#  'blister': 7,
#  'bloat': 6,
#  'bloc': 7,
#  'block': 237,
#  'blockbust': 14,
#  'blohorn': 9,
#  'blood': 37,
#  'bloodbath': 7,
#  'bloodi': 19,
#  'bloodless': 7,
#  'bloomer': 11,
#  'blow': 56,
#  'blue': 66,
#  'blueprint': 10,
#  'blunt': 9,
#  'bnp': 9,
#  'board': 497,
#  'boardroom': 10,
#  'boast': 10,
#  'boat': 29,
#  'boatmen': 13,
#  'boaz': 7,
#  'bob': 64,
#  'boc': 17,
#  'boca': 6,
#  'boddington': 10,
#  'bode': 7,
#  'bodi': 254,
#  'boe': 407,
#  'bogi': 6,
#  'bogota': 29,
#  'boil': 6,
#  'bold': 24,
#  'bollenbach': 9,
#  'bollor': 11,
#  'bolster': 39,
#  'bolt': 14,
#  'bomb': 66,
#  'bombardi': 7,
#  'bomber': 18,
#  'bond': 175,
#  'bone': 9,
#  'bonfield': 31,
#  'bonn': 9,
#  'bonni': 7,
#  'bonu': 38,
#  'bonus': 14,
#  'book': 149,
#  'boom': 96,
#  'boomer': 9,
#  'boomtown': 7,
#  'boost': 447,
#  'boot': 8,
#  'booth': 6,
#  'boral': 14,
#  'border': 105,
#  'bore': 17,
#  'boreali': 10,
#  'borg': 15,
#  'bori': 33,
#  'borjeix': 6,
#  'born': 53,
#  'borneo': 6,
#  'borrow': 73,
#  'boss': 39,
#  'boston': 53,
#  'bosworth': 19,
#  'bother': 9,
#  'bottl': 21,
#  'bottom': 93,
#  'boucher': 9,
#  'bought': 181,
#  'bounc': 16,
#  'bound': 42,
#  'bours': 64,
#  'boutiqu': 18,
#  'boutro': 15,
#  'bouygu': 28,
#  'bow': 20,
#  'bowl': 11,
#  'bowler': 8,
#  'box': 72,
#  'boxi': 6,
#  'boy': 28,
#  'boycot': 15,
#  'boyd': 6,
#  'bp': 59,
#  'bpd': 27,
#  'brace': 19,
#  'brad': 7,
#  'bradley': 7,
#  'bradshaw': 6,
#  'brain': 13,
#  'brake': 28,
#  'brambl': 34,
#  'branch': 74,
#  'brand': 258,
#  'brandt': 7,
#  'branson': 16,
#  'bratislava': 20,
#  'bratsk': 20,
#  'brave': 11,
#  'brazil': 29,
#  'brazilian': 12,
#  'bre': 385,
#  'breach': 35,
#  'bread': 9,
#  'break': 235,
#  'breakdown': 10,
#  'breakeven': 7,
#  'breakfast': 9,
#  'breakthrough': 21,
#  'breakup': 14,
#  'breath': 14,
#  'breed': 23,
#  'brentano': 6,
#  'breton': 11,
#  'brew': 55,
#  'brewer': 88,
#  'breweri': 52,
#  'brian': 38,
#  'bribe': 17,
#  'briberi': 6,
#  'brick': 8,
#  'bridg': 13,
#  'brief': 112,
#  'briefli': 10,
#  'brier': 7,
#  'bright': 26,
#  'brighter': 10,
#  'bring': 288,
#  'brink': 15,
#  'brisban': 14,
#  'brisk': 31,
#  'bristol': 9,
#  'britain': 711,
#  'britann': 12,
#  'britian': 6,
#  'british': 1321,
#  'briton': 17,
#  'brittan': 17,
#  'broad': 74,
#  'broadband': 8,
#  'broadcast': 226,
#  'broaden': 14,
#  'broader': 44,
#  'broadli': 26,
#  'broadvis': 6,
#  'brodi': 6,
#  'broe': 10,
#  'broke': 67,
#  'broken': 54,
#  'broker': 289,
#  'brokerag': 169,
#  'brook': 17,
#  'brother': 126,
#  'brotherhood': 7,
#  'brought': 128,
#  'broughton': 12,
#  'brown': 138,
#  'brows': 12,
#  'browser': 67,
#  'bruce': 19,
#  'brundag': 6,
#  'brush': 10,
#  'brussel': 15,
#  'brutal': 11,
#  'bse': 8,
#  'bskyb': 122,
#  'bt': 492,
#  'bu': 37,
#  'bubbl': 32,
#  'bucharest': 16,
#  'buck': 14,
#  'bucket': 7,
#  'budapest': 19,
#  'buddhism': 7,
#  'buddhist': 28,
#  'budget': 254,
#  'bug': 7,
#  'buick': 22,
#  'build': 638,
#  'builder': 8,
#  'built': 162,
#  'bulgaria': 7,
#  'bulk': 66,
#  'bull': 45,
#  'bullet': 6,
#  'bullfight': 8,
#  'bullion': 27,
#  'bullish': 61,
#  'bullock': 8,
#  'bump': 12,
#  'bumper': 22,
#  'bumpi': 6,
#  'bunch': 9,
#  'bund': 9,
#  'bundl': 17,
#  'buoy': 28,
#  'buoyant': 27,
#  'burden': 26,
#  'bureau': 130,
#  'bureaucraci': 13,
#  'bureaucrat': 15,
#  'burgeon': 15,
#  'burger': 21,
#  'burlingam': 10,
#  'burma': 6,
#  'burn': 63,
#  'burner': 6,
#  'burnham': 19,
#  'burst': 14,
#  'burton': 10,
#  'busang': 152,
#  'buse': 6,
#  'bush': 23,
#  'bushel': 9,
#  'bushnel': 6,
#  'busi': 2314,
#  'busiest': 15,
#  'businessman': 41,
#  'businessmen': 39,
#  'bust': 15,
#  'butcher': 22,
#  'butter': 14,
#  'butterworth': 25,
#  'bux': 10,
#  'buy': 872,
#  'buyback': 66,
#  'buyer': 294,
#  'buyout': 19,
#  'buzz': 8,
#  'byatt': 14,
#  'bypass': 19,
#  'bzw': 60,
#  'ca': 41,
#  'cabinet': 113,
#  'cabl': 424,
#  'cablecomm': 10,
#  'cablemedia': 20,
#  'cadillac': 10,
#  'cadtic': 8,
#  'cafe': 9,
#  'cai': 7,
#  'cairn': 6,
#  'caiss': 10,
#  'caistab': 68,
#  'cake': 12,
#  'calcul': 68,
#  'caledonia': 6,
#  'calendar': 57,
#  'calenergi': 45,
#  'calgari': 14,
#  'cali': 20,
#  'calif': 88,
#  'california': 131,
#  'call': 1176,
#  'callan': 8,
#  'caller': 22,
#  'calm': 25,
#  'calper': 21,
#  'cambier': 6,
#  'cambridg': 13,
#  'camdessu': 9,
#  'came': 291,
#  'camelot': 12,
#  'camera': 32,
#  'camp': 72,
#  'campaign': 237,
#  'campbel': 19,
#  'campu': 6,
#  'can': 6,
#  'canada': 535,
#  'canadian': 504,
#  'canadien': 17,
#  'canal': 25,
#  'canari': 11,
#  'canberra': 10,
#  'cancel': 102,
#  'cancer': 106,
#  'candid': 204,
#  'candidaci': 7,
#  'cane': 11,
#  'cannot': 186,
#  'canon': 6,
#  'cantal': 6,
#  'cao': 8,
#  'cap': 58,
#  'capabl': 68,
#  'capac': 272,
#  'capel': 9,
#  'capit': 666,
#  'capita': 8,
#  'capitalis': 79,
#  'capitalist': 45,
#  'capitol': 8,
#  'capq': 23,
#  'captiv': 8,
#  'captur': 39,
#  'car': 478,
#  'caravan': 7,
#  'card': 170,
#  'cardena': 8,
#  'care': 141,
#  'career': 30,
#  'carey': 13,
#  'cargil': 10,
#  'cargo': 288,
#  'caribbean': 23,
#  'carl': 20,
#  'carlo': 24,
#  'carlsberg': 24,
#  'carlton': 31,
#  'carmak': 13,
#  'carmel': 10,
#  'carniv': 12,
#  'carol': 8,
#  'carolina': 10,
#  'carpent': 13,
#  'carpet': 10,
#  'carr': 8,
#  'carri': 278,
#  'carriag': 11,
#  'carrier': 342,
#  'carrot': 8,
#  'carson': 8,
#  'cart': 6,
#  'cartel': 30,
#  'carter': 27,
#  'cartoon': 6,
#  'carv': 17,
#  ...}

# %% [markdown]
# ### Création de l'Index
#
# Afin de trouver rapidement les documents qui contiennent un certain mot, il a fallu créer un index. On a choisit de faire un index de la forme suivante : \\
#     {"token1" : {"total_occurences" : 4, \
#                          article1 : {"locations" : [12, 13, 14],
#                                  "occurences" : 3}, \
#                          article2 : {"locations" : [9],
#                                  "occurences" : 1}}}
#
# Nous avons d'abord essayer de créer l'index avec une programmation simple comprenant différentes boucles.    --> temps ? pour comparaisons
#
# L'index est crée selon les specifications de la fonction __create_index_from_text(...)__ dont les explications sont disponibles dans __utils.py__. Pour accélerer le calcul, nous utilisons le modèle _MapReduce_. Le __mapper__ ici correspond à la création de l'index pour un seul document, le __reducer__ correspond à l'_addition_ des index obtenus.
#
# La fonction  __create_index_from_text(...)__  s'utilise sur les textes brutes car la fonction de préparation du texte est utilisée à l'intérieur de notre fonction.

# %%
# %%time
index_simple = create_index(vocabulary_dict, texts)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/sharedfolder/utils_renan.py in create_index(vocabulary_dict, texts)
#     223             if word in index.keys():
#     224                 #n°document
# --> 225                 index[word][texts.index(getattr(row, "Text"))] = dict()
#     226                 #locations
#     227                 index[word][text.index(getattr(row, "Text"))]['locations'] = get_indexes_of_word(getattr(row, "BagOfWords"), word)
#
# TypeError: 'RangeIndex' object is not callable

# %%
# %%time 
index = reduce(sum_two_indexes, list(map(lambda x : create_index_from_text(texts.Text[x], x), range(len(texts)))))
# Out:
# CPU times: user 31 s, sys: 149 ms, total: 31.1 s
# Wall time: 31.1 s

# %% [markdown]
# ## Requêtes

# %% [markdown]
# ## Ranking
#
# ### Création de la matrice TF-IDF
#
# La matrice TF_IDF (la représation du corpus dans l'espace TF-IDF) est également créer suivant un modèle _MapReduce_, le __mapper__ étant le calcul du TF-IDF pour chaque documents d'un _token_, le __reducer__ étant une simple concaténation.

# %%
# %%time
tokens_count = generate_tokens_count(index)
matrix_tfidf = np.concatenate(list(map(lambda token: calculate_tf_idf_for_token(index[token], tokens_count), list(index.keys()))), axis=1)
# Out:
# CPU times: user 2.49 s, sys: 132 ms, total: 2.63 s
# Wall time: 2.62 s

# %% [markdown]
# ### Mise en place d'une requête du corpus
#
# Pour requêter (_query_) le corpus, nous calculons simplement le produit scalaire de la représentation du texte de la requête dans l'espace TF-IDF par la matrice. Le calcul du TF-IDF se fait comme si la requête était un nouvel article du corpus.

# %%
# %%time
query_corpus("british dairy", index, matrix_tfidf, texts, nb_to_show=20)
# Out:
# CPU times: user 105 ms, sys: 3.94 ms, total: 109 ms
# Wall time: 94 ms
#       DotProduct                                               Text  \
# 2010    0.321888  British food producer Northern Foods Plc poste...
# 2014    0.238622  Britain's Northern Foods sees world dairy comm...
# 2047    0.194796  British dairy and distribution company Unigate...
# 2030    0.121621  British dairy and distribution company Unigate...
# 2338    0.062595  Dairy and fruit juice group National Foods Ltd...
# 1848    0.043480  Britain's Home Office has warned ethnic minori...
# 1146    0.042589  British Telecom Sunday formally announced its ...
# 2398    0.040190  The three-year-old partnership between British...
# 1153    0.039991  Are you a businessman looking for generous tax...
# 2471    0.039762  British Telecom and MCI Communications Sunday ...
# 2397    0.036448  The three-year-old partnership between British...
# 2018    0.032851  Family-controlled British food and retailing g...
# 115     0.031272  The planned $20 billion merger of British Tele...
# 546     0.030505  Privatised nuclear power generator British Ene...
# 1716    0.027298  Britain entered new talks with China on Hong K...
# 1748    0.026766  The Hong Kong government was in a flap on Thur...
# 2489    0.026122  MCI Communications Corp., the No. 2 long dista...
# 2482    0.026122  MCI Communications Corp., the No. 2 long dista...
# 516     0.025854  Britain's nuclear generator British Energy Plc...
# 2461    0.025821  British Telecom and MCI Communications on Sund...
#
#                Author DocumentId
# 2010      Tim Farrand     202017
# 2014      Tim Farrand     204606
# 2047      Tim Farrand     201017
# 2030      Tim Farrand     199222
# 2338   Bernard Hickey      30677
# 1848       Tan Ee Lyn     380733
# 1146   Kirstin Ridley     162195
# 2398      Robin Sidel     144598
# 1153   Jane Macartney     105215
# 2471       Nick Louth     162521
# 2397      Robin Sidel     140433
# 2018      Tim Farrand     159528
# 115        Keith Weir     163109
# 546   Jo Winterbottom     105972
# 1716   Peter Humphrey     235690
# 1748   Peter Humphrey     238764
# 2489       Nick Louth     159997
# 2482       Nick Louth     160344
# 516   Jo Winterbottom     103380
# 2461       Nick Louth     164659
